# %%
import pandas as pd
engr = pd.read_excel('Engineering.xlsx')

# %%
engr
# Out:
#           Student Name Department fee  MTH 102  CIT 142  PHY 192  BIO 101
# 0       Samson Popoola           paid       45       69       55       80
# 1        Abike Omotayo           paid       23       73       45       75
# 2       Chinedu Okafor         unpaid       67       56       56       90
# 3         Bisola Alabi           paid       54       87       34       74
# 4     Inemesit Patrick           paid       66       78       50       68
# 5      Moshood Ololade           paid       47       60       56       45
# 6    Akinnibosun Funke         unpaid       79       63       89       60
# 7        Vivian Udeogu           paid       88       45       39       57
# 8      Temitope Kazeem           paid       56       89       72       89
# 9       Okosun Mistura           paid       40       56       74       30
# 10      Pascal Ifeanyi         unpaid       50       71       65       40
# 11      Obafemi Badmus           paid       40       63       48       87
# ...

# %%
engr.columns
# Out:
# Index(['Student Name', 'Department fee', 'MTH 102', 'CIT 142', 'PHY 192',
#        'BIO 101'],
#       dtype='object')

# %%
engr.dtypes
# Out:
# Student Name      object
# Department fee    object
# MTH 102            int64
# CIT 142            int64
# PHY 192            int64
# BIO 101            int64
# dtype: object

# %%
engr[["TOTAL","MINIMUM"]] = ["",""]

# %%
engr
# Out:
#           Student Name Department fee  MTH 102  CIT 142  PHY 192  BIO 101  \
# 0       Samson Popoola           paid       45       69       55       80
# 1        Abike Omotayo           paid       23       73       45       75
# 2       Chinedu Okafor         unpaid       67       56       56       90
# 3         Bisola Alabi           paid       54       87       34       74
# 4     Inemesit Patrick           paid       66       78       50       68
# 5      Moshood Ololade           paid       47       60       56       45
# 6    Akinnibosun Funke         unpaid       79       63       89       60
# 7        Vivian Udeogu           paid       88       45       39       57
# 8      Temitope Kazeem           paid       56       89       72       89
# 9       Okosun Mistura           paid       40       56       74       30
# 10      Pascal Ifeanyi         unpaid       50       71       65       40
# 11      Obafemi Badmus           paid       40       63       48       87
# ...

# %%
engr[["MTH 102","CIT 142","PHY 192","BIO 101"]].sum()
# Out:
# MTH 102    715
# CIT 142    855
# PHY 192    750
# BIO 101    864
# dtype: int64

# %%
summ = engr[["MTH 102","CIT 142","PHY 192","BIO 101"]].sum(axis=1)

# %%
summ
# Out:
# 0     249
# 1     216
# 2     269
# 3     249
# 4     262
# 5     208
# 6     291
# 7     229
# 8     306
# 9     200
# 10    226
# 11    238
# 12    241
# dtype: int64

# %%
engr["TOTAL"] = summ

# %%
engr
# Out:
#           Student Name Department fee  MTH 102  CIT 142  PHY 192  BIO 101  \
# 0       Samson Popoola           paid       45       69       55       80
# 1        Abike Omotayo           paid       23       73       45       75
# 2       Chinedu Okafor         unpaid       67       56       56       90
# 3         Bisola Alabi           paid       54       87       34       74
# 4     Inemesit Patrick           paid       66       78       50       68
# 5      Moshood Ololade           paid       47       60       56       45
# 6    Akinnibosun Funke         unpaid       79       63       89       60
# 7        Vivian Udeogu           paid       88       45       39       57
# 8      Temitope Kazeem           paid       56       89       72       89
# 9       Okosun Mistura           paid       40       56       74       30
# 10      Pascal Ifeanyi         unpaid       50       71       65       40
# 11      Obafemi Badmus           paid       40       63       48       87
# ...

# %%
min1 = engr[["MTH 102","CIT 142","PHY 192","BIO 101"]].min(axis=1)

# %%
min1
# Out:
# 0     45
# 1     23
# 2     56
# 3     34
# 4     50
# 5     45
# 6     60
# 7     39
# 8     56
# 9     30
# 10    40
# 11    40
# 12    45
# dtype: int64

# %%
engr["MINIMUM"] = min1

# %%
engr
# Out:
#           Student Name Department fee  MTH 102  CIT 142  PHY 192  BIO 101  \
# 0       Samson Popoola           paid       45       69       55       80
# 1        Abike Omotayo           paid       23       73       45       75
# 2       Chinedu Okafor         unpaid       67       56       56       90
# 3         Bisola Alabi           paid       54       87       34       74
# 4     Inemesit Patrick           paid       66       78       50       68
# 5      Moshood Ololade           paid       47       60       56       45
# 6    Akinnibosun Funke         unpaid       79       63       89       60
# 7        Vivian Udeogu           paid       88       45       39       57
# 8      Temitope Kazeem           paid       56       89       72       89
# 9       Okosun Mistura           paid       40       56       74       30
# 10      Pascal Ifeanyi         unpaid       50       71       65       40
# 11      Obafemi Badmus           paid       40       63       48       87
# ...

# %%
engr["Department fee"].value_counts()
# Out:
# paid      9
# unpaid    4
# Name: Department fee, dtype: int64

# %%
engr.sort_values("Student Name")
# Out:
#           Student Name Department fee  MTH 102  CIT 142  PHY 192  BIO 101  \
# 1        Abike Omotayo           paid       23       73       45       75
# 12  Akinleye Testimony         unpaid       60       45       67       69
# 6    Akinnibosun Funke         unpaid       79       63       89       60
# 3         Bisola Alabi           paid       54       87       34       74
# 2       Chinedu Okafor         unpaid       67       56       56       90
# 4     Inemesit Patrick           paid       66       78       50       68
# 5      Moshood Ololade           paid       47       60       56       45
# 11      Obafemi Badmus           paid       40       63       48       87
# 9       Okosun Mistura           paid       40       56       74       30
# 10      Pascal Ifeanyi         unpaid       50       71       65       40
# 0       Samson Popoola           paid       45       69       55       80
# 8      Temitope Kazeem           paid       56       89       72       89
# ...

# %%
engr.sort_values("TOTAL",ascending = False)
# Out:
#           Student Name Department fee  MTH 102  CIT 142  PHY 192  BIO 101  \
# 8      Temitope Kazeem           paid       56       89       72       89
# 6    Akinnibosun Funke         unpaid       79       63       89       60
# 2       Chinedu Okafor         unpaid       67       56       56       90
# 4     Inemesit Patrick           paid       66       78       50       68
# 0       Samson Popoola           paid       45       69       55       80
# 3         Bisola Alabi           paid       54       87       34       74
# 12  Akinleye Testimony         unpaid       60       45       67       69
# 11      Obafemi Badmus           paid       40       63       48       87
# 7        Vivian Udeogu           paid       88       45       39       57
# 10      Pascal Ifeanyi         unpaid       50       71       65       40
# 1        Abike Omotayo           paid       23       73       45       75
# 5      Moshood Ololade           paid       47       60       56       45
# ...

# %%
engr
# Out:
#           Student Name Department fee  MTH 102  CIT 142  PHY 192  BIO 101  \
# 0       Samson Popoola           paid       45       69       55       80
# 1        Abike Omotayo           paid       23       73       45       75
# 2       Chinedu Okafor         unpaid       67       56       56       90
# 3         Bisola Alabi           paid       54       87       34       74
# 4     Inemesit Patrick           paid       66       78       50       68
# 5      Moshood Ololade           paid       47       60       56       45
# 6    Akinnibosun Funke         unpaid       79       63       89       60
# 7        Vivian Udeogu           paid       88       45       39       57
# 8      Temitope Kazeem           paid       56       89       72       89
# 9       Okosun Mistura           paid       40       56       74       30
# 10      Pascal Ifeanyi         unpaid       50       71       65       40
# 11      Obafemi Badmus           paid       40       63       48       87
# ...

# %%
engr.sort_values("Student Name").reset_index(drop= True)
# Out:
#           Student Name Department fee  MTH 102  CIT 142  PHY 192  BIO 101  \
# 0        Abike Omotayo           paid       23       73       45       75
# 1   Akinleye Testimony         unpaid       60       45       67       69
# 2    Akinnibosun Funke         unpaid       79       63       89       60
# 3         Bisola Alabi           paid       54       87       34       74
# 4       Chinedu Okafor         unpaid       67       56       56       90
# 5     Inemesit Patrick           paid       66       78       50       68
# 6      Moshood Ololade           paid       47       60       56       45
# 7       Obafemi Badmus           paid       40       63       48       87
# 8       Okosun Mistura           paid       40       56       74       30
# 9       Pascal Ifeanyi         unpaid       50       71       65       40
# 10      Samson Popoola           paid       45       69       55       80
# 11     Temitope Kazeem           paid       56       89       72       89
# ...

# %%
engr.loc[3,"Student Name"] = "Amaka Uche"

# %%
engr
# Out:
#           Student Name Department fee  MTH 102  CIT 142  PHY 192  BIO 101  \
# 0       Samson Popoola           paid       45       69       55       80
# 1        Abike Omotayo           paid       23       73       45       75
# 2       Chinedu Okafor         unpaid       67       56       56       90
# 3           Amaka Uche           paid       54       87       34       74
# 4     Inemesit Patrick           paid       66       78       50       68
# 5      Moshood Ololade           paid       47       60       56       45
# 6    Akinnibosun Funke         unpaid       79       63       89       60
# 7        Vivian Udeogu           paid       88       45       39       57
# 8      Temitope Kazeem           paid       56       89       72       89
# 9       Okosun Mistura           paid       40       56       74       30
# 10      Pascal Ifeanyi         unpaid       50       71       65       40
# 11      Obafemi Badmus           paid       40       63       48       87
# ...

# %%
engr.iloc[10,0] = "Tolani Kekere-ekun"

# %%
engr
# Out:
#           Student Name Department fee  MTH 102  CIT 142  PHY 192  BIO 101  \
# 0       Samson Popoola           paid       45       69       55       80
# 1        Abike Omotayo           paid       23       73       45       75
# 2       Chinedu Okafor         unpaid       67       56       56       90
# 3           Amaka Uche           paid       54       87       34       74
# 4     Inemesit Patrick           paid       66       78       50       68
# 5      Moshood Ololade           paid       47       60       56       45
# 6    Akinnibosun Funke         unpaid       79       63       89       60
# 7        Vivian Udeogu           paid       88       45       39       57
# 8      Temitope Kazeem           paid       56       89       72       89
# 9       Okosun Mistura           paid       40       56       74       30
# 10  Tolani Kekere-ekun         unpaid       50       71       65       40
# 11      Obafemi Badmus           paid       40       63       48       87
# ...

# %%
engr.loc[5,"Student Name"]
# Out:
# 'Moshood Ololade'

# %%
engr.iloc[10,0]
# Out:
# 'Tolani Kekere-ekun'

# %%
engr.loc[10]
# Out:
# Student Name      Tolani Kekere-ekun
# Department fee                unpaid
# MTH 102                           50
# CIT 142                           71
# PHY 192                           65
# BIO 101                           40
# TOTAL                            226
# MINIMUM                           40
# Name: 10, dtype: object

# %%
engr.head(6)
# Out:
#        Student Name Department fee  MTH 102  CIT 142  PHY 192  BIO 101  TOTAL  \
# 0    Samson Popoola           paid       45       69       55       80    249
# 1     Abike Omotayo           paid       23       73       45       75    216
# 2    Chinedu Okafor         unpaid       67       56       56       90    269
# 3        Amaka Uche           paid       54       87       34       74    249
# 4  Inemesit Patrick           paid       66       78       50       68    262
# 5   Moshood Ololade           paid       47       60       56       45    208
#
#    MINIMUM
# 0       45
# 1       23
# 2       56
# 3       34
# 4       50
# 5       45

# %%
engr.iloc[7:11]
# Out:
#           Student Name Department fee  MTH 102  CIT 142  PHY 192  BIO 101  \
# 7        Vivian Udeogu           paid       88       45       39       57
# 8      Temitope Kazeem           paid       56       89       72       89
# 9       Okosun Mistura           paid       40       56       74       30
# 10  Tolani Kekere-ekun         unpaid       50       71       65       40
#
#     TOTAL  MINIMUM
# 7     229       39
# 8     306       56
# 9     200       30
# 10    226       40

# %%
engr.tail(3)
# Out:
#           Student Name Department fee  MTH 102  CIT 142  PHY 192  BIO 101  \
# 10  Tolani Kekere-ekun         unpaid       50       71       65       40
# 11      Obafemi Badmus           paid       40       63       48       87
# 12  Akinleye Testimony         unpaid       60       45       67       69
#
#     TOTAL  MINIMUM
# 10    226       40
# 11    238       40
# 12    241       45
