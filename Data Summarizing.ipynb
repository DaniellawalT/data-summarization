# %%
import pandas as pd
order = pd.read_excel("orders 1.xlsx")

# %%
order
# Out:
#     Order no.       Date  Driver's name             Item  Number of items  \
# 0      100001 2013-02-01       John May               TV               25
# 1      100002 2013-02-01    Peter White  washing machine               30
# 2      100003 2013-02-02     Carl Nowak  washing machine               15
# 3      100004 2013-02-03    Peter White               TV               32
# 4      100005 2013-02-03  George Ramsay     refrigerator               25
# 5      100006 2013-02-03     Carl Nowak  washing machine               18
# 6      100007 2013-02-03       John May     refrigerator               15
# 7      100008 2013-02-04     Carl Nowak     refrigerator               25
# 8      100009 2013-02-04    Peter White               TV               30
# 9      100010 2013-02-04  George Ramsay     refrigerator               15
# 10     100011 2013-02-04    Mertl Pavel        microwave               25
# 11     100012 2013-02-04       John May  washing machine               14
# ...

# %%
order["Destination"].value_counts()
# Out:
# NY              6
# Philadelphia    6
# Baltimore       5
# Boston          4
# Michigan        3
# Name: Destination, dtype: int64

# %%
order.dtypes
# Out:
# Order no.                   int64
# Date               datetime64[ns]
# Driver's name              object
# Item                       object
# Number of items             int64
# Transport                  object
# Destination                object
# dtype: object

# %%
order["Number of items"].sum()
# Out:
# 551

# %%
order["Item"].value_counts()
# Out:
# washing machine    8
# TV                 6
# refrigerator       5
# microwave          5
# Name: Item, dtype: int64

# %%
order["Item"].count()
# Out:
# 24

# %%
order = order.sort_values("Driver's name").reset_index(drop=True)

order
# Out:
#     Order no.       Date  Driver's name             Item  Number of items  \
# 0      100021 2013-02-08     Carl Nowak        microwave               30
# 1      100003 2013-02-02     Carl Nowak  washing machine               15
# 2      100006 2013-02-03     Carl Nowak  washing machine               18
# 3      100008 2013-02-04     Carl Nowak     refrigerator               25
# 4      100014 2013-02-05     Carl Nowak               TV               30
# 5      100024 2013-02-09  George Ramsay  washing machine               34
# 6      100019 2013-02-08  George Ramsay  washing machine               13
# 7      100005 2013-02-03  George Ramsay     refrigerator               25
# 8      100010 2013-02-04  George Ramsay     refrigerator               15
# 9      100015 2013-02-05  George Ramsay        microwave               15
# 10     100018 2013-02-07       John May               TV               30
# 11     100017 2013-02-06       John May        microwave               25
# ...

# %%
order["Driver's name"] == "Peter White"
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# Name: Driver's name, dtype: bool

# %%
order.loc[order["Driver's name"] == "Peter White"]
# Out:
#     Order no.       Date Driver's name             Item  Number of items  \
# 18     100016 2013-02-05   Peter White               TV               15
# 19     100009 2013-02-04   Peter White               TV               30
# 20     100004 2013-02-03   Peter White               TV               32
# 21     100020 2013-02-08   Peter White     refrigerator               25
# 22     100002 2013-02-01   Peter White  washing machine               30
# 23     100022 2013-02-08   Peter White  washing machine               15
#
#    Transport   Destination
# 18   truck 1      Michigan
# 19   truck 1      Michigan
# 20   truck 4            NY
# 21   truck 2  Philadelphia
# 22   truck 3            NY
# 23  airplane            NY

# %%
order.loc[order["Item"] == "washing machine"]
# Out:
#     Order no.       Date  Driver's name             Item  Number of items  \
# 1      100003 2013-02-02     Carl Nowak  washing machine               15
# 2      100006 2013-02-03     Carl Nowak  washing machine               18
# 5      100024 2013-02-09  George Ramsay  washing machine               34
# 6      100019 2013-02-08  George Ramsay  washing machine               13
# 15     100013 2013-02-05       John May  washing machine               25
# 16     100012 2013-02-04       John May  washing machine               14
# 22     100002 2013-02-01    Peter White  washing machine               30
# 23     100022 2013-02-08    Peter White  washing machine               15
#
#    Transport   Destination
# 1    truck 3  Philadelphia
# 2    truck 1     Baltimore
# 5    truck 3     Baltimore
# 6    truck 3     Baltimore
# 15  airplane     Baltimore
# 16   truck 4            NY
# 22   truck 3            NY
# 23  airplane            NY

# %%
order.loc[order["Number of items"]>= 25]
# Out:
#     Order no.       Date  Driver's name             Item  Number of items  \
# 0      100021 2013-02-08     Carl Nowak        microwave               30
# 3      100008 2013-02-04     Carl Nowak     refrigerator               25
# 4      100014 2013-02-05     Carl Nowak               TV               30
# 5      100024 2013-02-09  George Ramsay  washing machine               34
# 7      100005 2013-02-03  George Ramsay     refrigerator               25
# 10     100018 2013-02-07       John May               TV               30
# 11     100017 2013-02-06       John May        microwave               25
# 12     100001 2013-02-01       John May               TV               25
# 13     100023 2013-02-08       John May        microwave               25
# 15     100013 2013-02-05       John May  washing machine               25
# 17     100011 2013-02-04    Mertl Pavel        microwave               25
# 19     100009 2013-02-04    Peter White               TV               30
# ...

# %%
order.groupby("Item").sum()
# Out:
#                  Order no.  Number of items
# Item
# TV                  600062              162
# microwave           500087              120
# refrigerator        500050              105
# washing machine     800101              164

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
order.nunique()
# Out:
# Order no.          24
# Date                9
# Driver's name       5
# Item                4
# Number of items     8
# Transport           5
# Destination         5
# dtype: int64

# %%
order.groupby("Item").max()
# Out:
#                  Order no.       Date Driver's name  Number of items  \
# Item
# TV                  100018 2013-02-07   Peter White               32
# microwave           100023 2013-02-08   Mertl Pavel               30
# refrigerator        100020 2013-02-08   Peter White               25
# washing machine     100024 2013-02-09   Peter White               34
#
#                 Transport   Destination
# Item
# TV                truck 4  Philadelphia
# microwave         truck 4  Philadelphia
# refrigerator      truck 3  Philadelphia
# washing machine   truck 4  Philadelphia

# %%
order.groupby("Item").min()
# Out:
#                  Order no.       Date Driver's name  Number of items  \
# Item
# TV                  100001 2013-02-01    Carl Nowak               15
# microwave           100011 2013-02-04    Carl Nowak               15
# refrigerator        100005 2013-02-03    Carl Nowak               15
# washing machine     100002 2013-02-01    Carl Nowak               13
#
#                 Transport Destination
# Item
# TV                truck 1      Boston
# microwave         truck 1      Boston
# refrigerator      truck 2   Baltimore
# washing machine  airplane   Baltimore
